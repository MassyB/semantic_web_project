# %% [markdown]
# # Semantic Web Project
# This is an application using the **[InShowTimes API](https://www.internationalshowtimes.com/)** to retrieve a movies list ,of category **c**, playing in theaters colse to a position **p**. The functions that use InShowTimes API are in **`showtimes.py`**

# %%
import re
import requests

# %% [markdown]
# The query is

# %%
query = "What are the drama movies nearby me"

# %% [markdown]
# ## Query analysis : extract the category and the position

# %% [markdown]
# ### the Category
# a RegEx is used to extract the category form the query

# %%
category = "" ## the variable that holds the category
categoryRegEx = re.compile(r'What are the (?P<category>\w+).*') ##use a regEx

matchObj = categoryRegEx.match(query)
if matchObj:
    category = matchObj.group("category")
    
print("the category of movies searched for is "+ category)
# Out:
# the category of movies searched for is drama

# %% [markdown]
# ### the position
# a position is choosen randomly from a dict of positions. Each key of **`positions`** is a country and the corresponding value is a _localisation_: longitude, latitude and addresse

# %%
import random

positions = {
    "France": {"lat": 48.82, "long": 2.34, "add": "212 Rue de Tolbiac"},
    "Serbia" : {"lat": 44.80, "long":20.40, "add": "Jurija Gagarina 16-16a, Beograd 11070, Serbie"}, 
    "Turkey": {"lat": 41.05, "long": 28.99, "add": "Teşvikiye Cad. City's Nişantaşı Alışveriş Merkezi No:162, 34204 İstanbul, Turquie" } 
}

## positionKey = random.choice( list(positions.keys()) ) #choose a position 
positionKey = "France"
position = positions[positionKey]



print("the choosen position is " + positionKey+ "\n")
print(position)
# Out:
# the choosen position is France
#
# {'long': 2.34, 'lat': 48.82, 'add': '212 Rue de Tolbiac'}

# %% [markdown]
# ## Search For individuals
# ### Theaters close to `position`
# get a list of theaters such that the distance between the **`theater`** and **`position`**  is at moste equal to **`distance`**

# %%
from showtimes import getTheatersCloseTo


distance = 5 ## theaters are considered close if they are at most 5 KMs away from Position p.

theaters =  getTheatersCloseTo(position,distance)["cinemas"]
# Out:
# Response HTTP Status Code: 200
# Response HTTP Response Body:
#
# {'cinemas': [{'booking_type': None,
#               'chain_id': None,
#               'id': '58741',
#               'location': {'address': {'city': 'Paris 1er arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': 'Forum des Halles, 2 '
#                                                        'rue du Cinéma, 75001, '
#                                                        'Paris 1er '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': 'Forum des Halles, 2 rue du '
#                                                  'Cinéma',
#                                        'zipcode': '75001'},
#                            'lat': 48.8625,
#                            'lon': 2.34572},
#               'name': 'Forum des images',
#               'slug': 'forum-des-images-paris-1er-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '58777',
#               'location': {'address': {'city': 'Paris 5e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '7, place Saint-Michel, '
#                                                        '75005, Paris 5e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '7, place Saint-Michel',
#                                        'zipcode': '75005'},
#                            'lat': 48.8533,
#                            'lon': 2.34411},
#               'name': 'Espace Saint-Michel',
#               'slug': 'espace-saint-michel-paris-5e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '58869',
#               'location': {'address': {'city': 'Paris 6e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '30, rue '
#                                                        'Saint-Andre-des-Arts / '
#                                                        '12, rue Gît-le-Coeur, '
#                                                        '75006, Paris 6e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '30, rue Saint-Andre-des-Arts '
#                                                  '/ 12, rue Gît-le-Coeur',
#                                        'zipcode': '75006'},
#                            'lat': 48.8534,
#                            'lon': 2.34205},
#               'name': 'Saint-André des Arts ',
#               'slug': 'saint-andre-des-arts-paris-6e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '58897',
#               'location': {'address': {'city': 'Bagneux',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '14, Avenue Victor '
#                                                        'Hugo, 92220, Bagneux',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '14, Avenue Victor Hugo',
#                                        'zipcode': '92220'},
#                            'lat': 48.804,
#                            'lon': 2.32169},
#               'name': 'Théâtre-Cinéma Victor Hugo',
#               'slug': 'theatre-cinema-victor-hugo-bagneux',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '58900',
#               'location': {'address': {'city': 'Paris 7e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '1, rue de la '
#                                                        "Legion-d'Honneur, "
#                                                        '75007, Paris 7e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '1, rue de la '
#                                                  "Legion-d'Honneur",
#                                        'zipcode': '75007'},
#                            'lat': 48.8604,
#                            'lon': 2.32489},
#               'name': "Musee d'Orsay, Auditorium",
#               'slug': 'musee-d-orsay-auditorium-paris-7e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '58999',
#               'location': {'address': {'city': 'Paris 5e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '23, rue des Ecoles, '
#                                                        '75005, Paris 5e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '23, rue des Ecoles',
#                                        'zipcode': '75005'},
#                            'lat': 48.8484,
#                            'lon': 2.34894},
#               'name': 'Le Desperado ',
#               'slug': 'le-desperado-paris-5e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59057',
#               'location': {'address': {'city': 'Malakoff',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '17 rue Béranger, '
#                                                        '92240, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '17 rue Béranger',
#                                        'zipcode': '92240'},
#                            'lat': 48.8222,
#                            'lon': 2.30383},
#               'name': 'Cinéma Marcel-Pagnol',
#               'slug': 'cinema-marcel-pagnol-malakoff',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59085',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '10, rue des Ursulines, '
#                                                        '75005, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '10, rue des Ursulines',
#                                        'zipcode': '75005'},
#                            'lat': 48.8428,
#                            'lon': 2.34206},
#               'name': 'STUDIO DES URSULINES',
#               'slug': 'studio-des-ursulines-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59087',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '98 BOULEVARD DU '
#                                                        'MONTPARNASSE, 75014, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '98 BOULEVARD DU MONTPARNASSE',
#                                        'zipcode': '75014'},
#                            'lat': 48.8425,
#                            'lon': 2.32779},
#               'name': '7 PARNASSIENS',
#               'slug': '7-parnassiens-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59120',
#               'location': {'address': {'city': "L' Haÿ-les-Roses",
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '14, rue Dispan, 94240, '
#                                                        "L' Haÿ-les-Roses",
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '14, rue Dispan',
#                                        'zipcode': '94240'},
#                            'lat': 48.7798,
#                            'lon': 2.33923},
#               'name': 'La Tournelle',
#               'slug': 'la-tournelle-l-hay-les-roses',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59157',
#               'location': {'address': {'city': 'Ivry-sur-Seine',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '77, av. '
#                                                        'Georges-Gosnat, '
#                                                        '94200, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '77, av. Georges-Gosnat',
#                                        'zipcode': '94200'},
#                            'lat': 48.8136,
#                            'lon': 2.38919},
#               'name': 'Le Luxy',
#               'slug': 'le-luxy-ivry-sur-seine',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59166',
#               'location': {'address': {'city': 'Paris 5e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '51, rue des Ecoles, '
#                                                        '75005, Paris 5e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '51, rue des Ecoles',
#                                        'zipcode': '75005'},
#                            'lat': 48.85,
#                            'lon': 2.34323},
#               'name': 'Le Champo - Espace Jacques Tati',
#               'slug': 'le-champo-espace-jacques-tati-paris-5e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59261',
#               'location': {'address': {'city': 'Paris 4e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': 'pl. Georges-Pompidou, '
#                                                        '75004, Paris 4e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': 'pl. Georges-Pompidou',
#                                        'zipcode': '75004'},
#                            'lat': 48.8611,
#                            'lon': 2.35125},
#               'name': 'Centre Georges-Pompidou',
#               'slug': 'centre-georges-pompidou-paris-4e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59274',
#               'location': {'address': {'city': 'Montrouge',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '88, rue Racine, '
#                                                        '92120, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '88, rue Racine',
#                                        'zipcode': '92120'},
#                            'lat': 48.8134,
#                            'lon': 2.31058},
#               'name': 'Ciné Montrouge',
#               'slug': 'cine-montrouge',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59355',
#               'location': {'address': {'city': 'Paris 14e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': "16 Rue d'Odessa, "
#                                                        '75014, Paris 14e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': "16 Rue d'Odessa",
#                                        'zipcode': '75014'},
#                            'lat': 48.8421,
#                            'lon': 2.3246},
#               'name': 'Gaumont Parnasse côté Montparnos',
#               'slug': 'gaumont-parnasse-cote-montparnos-paris-14e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59441',
#               'location': {'address': {'city': 'Paris 11e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '5, rue du '
#                                                        'Faubourg-Saint-Antoine, '
#                                                        '75011, Paris 11e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '5, rue du '
#                                                  'Faubourg-Saint-Antoine',
#                                        'zipcode': '75011'},
#                            'lat': 48.8531,
#                            'lon': 2.37068},
#               'name': 'MK2 Bastille (côté Fg St Antoine)',
#               'slug': 'mk2-bastille-cote-fg-st-antoine-paris-11e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59443',
#               'location': {'address': {'city': 'Fontenay-aux-Roses',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '8, av. '
#                                                        'Jeanne-et-Maurice-Dolivet, '
#                                                        '92260, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '8, av. '
#                                                  'Jeanne-et-Maurice-Dolivet',
#                                        'zipcode': '92260'},
#                            'lat': 48.7925,
#                            'lon': 2.2903},
#               'name': 'Le Scarron',
#               'slug': 'le-scarron-fontenay-aux-roses',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59448',
#               'location': {'address': {'city': 'Cachan',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '12, av. '
#                                                        'Cousin-de-Mericourt, '
#                                                        '94230, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '12, av. Cousin-de-Mericourt',
#                                        'zipcode': '94230'},
#                            'lat': 48.7958,
#                            'lon': 2.3353},
#               'name': 'La Pleiade',
#               'slug': 'la-pleiade-cachan',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59470',
#               'location': {'address': {'city': 'Villejuif',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '18 rue Eugène Varlin, '
#                                                        '94800, Villejuif',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '18 rue Eugène Varlin',
#                                        'zipcode': '94800'},
#                            'lat': 48.7937,
#                            'lon': 2.36316},
#               'name': "Cinéma d'Art Romain Rolland",
#               'slug': 'cinema-d-art-romain-rolland-villejuif',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59507',
#               'location': {'address': {'city': 'Vitry-sur-Seine',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '19, avenue Maximilien '
#                                                        'Robespierre, 94400, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '19, avenue Maximilien '
#                                                  'Robespierre',
#                                        'zipcode': '94400'},
#                            'lat': 48.791,
#                            'lon': 2.38807},
#               'name': 'Les 3 Cinés - Robespierre',
#               'slug': 'les-3-cines-robespierre-vitry-sur-seine',
#               'telephone': None,
#               'website': None},
#              {'booking_type': None,
#               'chain_id': None,
#               'id': '59592',
#               'location': {'address': {'city': 'Arcueil',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '1, rue Paul Signac, '
#                                                        '94110, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '1, rue Paul Signac',
#                                        'zipcode': '94110'},
#                            'lat': 48.8013,
#                            'lon': 2.33079},
#               'name': 'Espace municipal Jean Vilar',
#               'slug': 'espace-municipal-jean-vilar-arcueil',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59789',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '34 Rue Daubenton, '
#                                                        '75005, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '34 Rue Daubenton',
#                                        'zipcode': '75005'},
#                            'lat': 48.8411,
#                            'lon': 2.35246},
#               'name': 'Cinéma la clef',
#               'slug': 'cinema-la-clef-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59812',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '5 rue des écoles, '
#                                                        '75005, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '5 rue des écoles',
#                                        'zipcode': '75005'},
#                            'lat': 48.8475,
#                            'lon': 2.35212},
#               'name': 'Le Grand Action',
#               'slug': 'le-grand-action-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59823',
#               'location': {'address': {'city': 'Arcueil',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '8, rue Salvator '
#                                                        'Allende\r'
#                                                        ', 94110, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '8, rue Salvator Allende\r',
#                                        'zipcode': '94110'},
#                            'lat': 48.8109,
#                            'lon': 2.32777},
#               'name': 'MÉGARAMA ARCUEIL',
#               'slug': 'megarama-arcueil',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59831',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '4 - 6 rue Louis '
#                                                        'Armand, 75015, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '4 - 6 rue Louis Armand',
#                                        'zipcode': '75015'},
#                            'lat': 48.831,
#                            'lon': 2.27699},
#               'name': 'Gaumont Aquaboulevard',
#               'slug': 'gaumont-aquaboulevard-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59832',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '27, rue Alain '
#                                                        'Chartier, 75015, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '27, rue Alain Chartier',
#                                        'zipcode': '75015'},
#                            'lat': 48.8378,
#                            'lon': 2.29643},
#               'name': 'Gaumont Convention',
#               'slug': 'gaumont-convention-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59836',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '42, Rue Galande, '
#                                                        '75005, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '42, Rue Galande',
#                                        'zipcode': '75005'},
#                            'lat': 48.8516,
#                            'lon': 2.34702},
#               'name': 'STUDIO GALANDE',
#               'slug': 'studio-galande-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59855',
#               'location': {'address': {'city': 'Paris 14e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '24, place '
#                                                        'Denfert-Rochereau, '
#                                                        '75014, Paris 14e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '24, place Denfert-Rochereau',
#                                        'zipcode': '75014'},
#                            'lat': 48.8339,
#                            'lon': 2.33124},
#               'name': 'Chaplin - Denfert',
#               'slug': 'chaplin-denfert-paris-14e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59873',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '11 boulevard du Port '
#                                                        'Royal, 75013, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '11 boulevard du Port Royal',
#                                        'zipcode': '75013'},
#                            'lat': 48.8369,
#                            'lon': 2.34982},
#               'name': 'ESCURIAL',
#               'slug': 'escurial-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': '77',
#               'id': '59895',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '12, rue de Lyon, '
#                                                        '75012, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '12, rue de Lyon',
#                                        'zipcode': '75012'},
#                            'lat': 48.8475,
#                            'lon': 2.37171},
#               'name': 'UGC Lyon Bastille',
#               'slug': 'ugc-lyon-bastille-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59901',
#               'location': {'address': {'city': 'Ivry-sur-Seine',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '5, rue François '
#                                                        'Mitterrand, 94200, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '5, rue François Mitterrand',
#                                        'zipcode': '94200'},
#                            'lat': 48.8249,
#                            'lon': 2.38918},
#               'name': "Pathé Quai d'Ivry",
#               'slug': 'pathe-quai-d-ivry-sur-seine',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59924',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '20 rue Cujas, 75005, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '20 rue Cujas',
#                                        'zipcode': '75005'},
#                            'lat': 48.8482,
#                            'lon': 2.34204},
#               'name': 'STUDIO ACCATONE',
#               'slug': 'studio-accatone-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59963',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '3 rue Champollion, '
#                                                        '75005, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '3 rue Champollion',
#                                        'zipcode': '75005'},
#                            'lat': 48.8497,
#                            'lon': 2.3429},
#               'name': 'REFLET MEDICIS',
#               'slug': 'reflet-medicis-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59969',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '4, Bd Richard Lenoir, '
#                                                        '75011, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '4, Bd Richard Lenoir',
#                                        'zipcode': '75011'},
#                            'lat': 48.8535,
#                            'lon': 2.36961},
#               'name': 'MAJESTIC BASTILLE',
#               'slug': 'majestic-bastille-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59985',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '73, avenue du Général '
#                                                        'Leclerc, 75014, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '73, avenue du Général '
#                                                  'Leclerc',
#                                        'zipcode': '75014'},
#                            'lat': 48.8286,
#                            'lon': 2.32756},
#               'name': 'Gaumont Alésia',
#               'slug': 'gaumont-alesia-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '59986',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '67 Rue Monsieur le '
#                                                        'Prince, 75006, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '67 Rue Monsieur le Prince',
#                                        'zipcode': '75006'},
#                            'lat': 48.8484,
#                            'lon': 2.34077},
#               'name': '3 LUXEMBOURG',
#               'slug': '3-luxembourg-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': '77',
#               'id': '60001',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '103, boulevard du '
#                                                        'Montparnasse, 75006, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '103, boulevard du '
#                                                  'Montparnasse',
#                                        'zipcode': '75006'},
#                            'lat': 48.8423,
#                            'lon': 2.32872},
#               'name': 'UGC Rotonde',
#               'slug': 'ugc-rotonde-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60046',
#               'location': {'address': {'city': 'Paris 4e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '20, rue du Temple, '
#                                                        '75004, Paris 4e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '20, rue du Temple',
#                                        'zipcode': '75004'},
#                            'lat': 48.8586,
#                            'lon': 2.35351},
#               'name': 'Luminor Hôtel de Ville',
#               'slug': 'luminor-hotel-de-ville-paris-4e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60048',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '76 rue de Rennes, '
#                                                        '75006, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '76 rue de Rennes',
#                                        'zipcode': '75006'},
#                            'lat': 48.8513,
#                            'lon': 2.33073},
#               'name': 'ARLEQUIN',
#               'slug': 'arlequin-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60324',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': "3, rue d'Odessa, "
#                                                        '75014, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': "3, rue d'Odessa",
#                                        'zipcode': '75014'},
#                            'lat': 48.843,
#                            'lon': 2.32438},
#               'name': 'Gaumont Parnasse',
#               'slug': 'gaumont-parnasse-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': '77',
#               'id': '60361',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': 'Forum des Halles - '
#                                                        'Niveau -3, 75001, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': 'Forum des Halles - Niveau -3',
#                                        'zipcode': '75001'},
#                            'lat': 48.8626,
#                            'lon': 2.34535},
#               'name': 'UGC Ciné Cité Les Halles',
#               'slug': 'ugc-cine-cite-les-halles-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': '77',
#               'id': '60362',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '83, boulevard du '
#                                                        'Montparnasse, 75006, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '83, boulevard du '
#                                                  'Montparnasse',
#                                        'zipcode': '75006'},
#                            'lat': 48.8433,
#                            'lon': 2.32552},
#               'name': 'UGC Montparnasse',
#               'slug': 'ugc-montparnasse-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': '77',
#               'id': '60365',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '2, cour Saint Emilion, '
#                                                        '75012, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '2, cour Saint Emilion',
#                                        'zipcode': '75012'},
#                            'lat': 48.8329,
#                            'lon': 2.38627},
#               'name': 'UGC Ciné Cité Bercy',
#               'slug': 'ugc-cine-cite-bercy-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': '77',
#               'id': '60367',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '99, boulevard '
#                                                        'Saint-Germain, 75006, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '99, boulevard Saint-Germain',
#                                        'zipcode': '75006'},
#                            'lat': 48.8521,
#                            'lon': 2.33907},
#               'name': 'UGC Danton',
#               'slug': 'ugc-danton-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60386',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '50 rue Rambuteau, '
#                                                        '75003, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '50 rue Rambuteau',
#                                        'zipcode': '75003'},
#                            'lat': 48.8615,
#                            'lon': 2.35267},
#               'name': 'Beaubourg',
#               'slug': 'beaubourg-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60387',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '128/162 av. de France, '
#                                                        '75013, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '128/162 av. de France',
#                                        'zipcode': '75013'},
#                            'lat': 48.8311,
#                            'lon': 2.37617},
#               'name': 'Bibliothèque (entrée BnF)',
#               'slug': 'bibliotheque-entree-bnf-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60388',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '128/162 av. de France, '
#                                                        '75013, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '128/162 av. de France',
#                                        'zipcode': '75013'},
#                            'lat': 48.8311,
#                            'lon': 2.37617},
#               'name': 'Bibliothèque',
#               'slug': 'bibliotheque-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60391',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '133, boulevard '
#                                                        'Diderot, 75012, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '133, boulevard Diderot',
#                                        'zipcode': '75012'},
#                            'lat': 48.8481,
#                            'lon': 2.3932},
#               'name': 'Nation',
#               'slug': 'nation-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60392',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': ' 113 bd Saint Germain, '
#                                                        '75006, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': ' 113 bd Saint Germain',
#                                        'zipcode': '75006'},
#                            'lat': 48.8526,
#                            'lon': 2.3381},
#               'name': 'Odéon (côté St Germain)',
#               'slug': 'odeon-cote-st-germain-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60393',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '11 rue Jules Chaplain, '
#                                                        '75006, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '11 rue Jules Chaplain',
#                                        'zipcode': '75006'},
#                            'lat': 48.8428,
#                            'lon': 2.33056},
#               'name': 'Parnasse',
#               'slug': 'parnasse-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60399',
#               'location': {'address': {'city': 'Paris 6e arrondissement',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '53, rue '
#                                                        'Notre-Dame-des-Champs, '
#                                                        '75006, Paris 6e '
#                                                        'arrondissement',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '53, rue '
#                                                  'Notre-Dame-des-Champs',
#                                        'zipcode': '75006'},
#                            'lat': 48.8442,
#                            'lon': 2.33041},
#               'name': 'Paris - Lucernaire',
#               'slug': 'paris-lucernaire-6e-arrondissement',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60425',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '6, rue Peclet, 75015, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '6, rue Peclet',
#                                        'zipcode': '75015'},
#                            'lat': 48.8431,
#                            'lon': 2.29863},
#               'name': 'Chaplin - St Lambert',
#               'slug': 'chaplin-st-lambert-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60426',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '58, avenue des '
#                                                        'Gobelins, 75013, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '58, avenue des Gobelins',
#                                        'zipcode': '75013'},
#                            'lat': 48.8336,
#                            'lon': 2.35397},
#               'name': 'Les Fauvettes',
#               'slug': 'les-fauvettes-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60439',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '7 rue Hautefeuille, '
#                                                        '75006, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '7 rue Hautefeuille',
#                                        'zipcode': '75006'},
#                            'lat': 48.8521,
#                            'lon': 2.34276},
#               'name': 'Odéon (côté St Michel)',
#               'slug': 'odeon-cote-st-michel-paris',
#               'telephone': None,
#               'website': None},
#              {'booking_type': 'external',
#               'chain_id': None,
#               'id': '60459',
#               'location': {'address': {'city': 'Paris',
#                                        'country': 'France',
#                                        'country_code': 'FR',
#                                        'display_text': '9 Rue Champollion, '
#                                                        '75005, ',
#                                        'house': None,
#                                        'state': None,
#                                        'state_abbr': None,
#                                        'street': '9 Rue Champollion',
#                                        'zipcode': '75005'},
#                            'lat': 48.8495,
#                            'lon': 2.34291},
#               'name': 'LA FILMOTHEQUE DU QUARTIER LATIN',
#               'slug': 'la-filmotheque-du-quartier-latin-paris',
#               'telephone': None,
#               'website': None}]}

# %%
print("the number of theaters obtained is {}".format(len(theaters)))
# Out:
# the number of theaters obtained is 55

# %% [markdown]
# ### `movies` that are playing in those theaters and are of category `category`
# for each nearby theater get the movies showing. Only those of category **`category`** are fetched

# %%
from showtimes import getMoviesPlayedInTheaters

movies = getMoviesPlayedInTheaters(theaters, category)
movies
# Out:
# [{'id': '12200',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vOipe2myi26UDwP978hsYOrnUWC.jpg',
#   'slug': 'the-jungle-book',
#   'title': 'The Jungle Book'},
#  {'id': '6035',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/y61Bcb1NeLvq7D1gAyqS1mtoYbd.jpg',
#   'slug': 'mein-leben-als-hund',
#   'title': 'My Life as a Dog'},
#  {'id': '20481',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/8dTWj3c74RDhXfSUZpuyVNJrgS.jpg',
#   'slug': 'mena',
#   'title': 'American Made'},
#  {'id': '31648',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/n8r5wste6GTihXsJmDnf3bMuwdJ.jpg',
#   'slug': 'mon-garcon',
#   'title': 'Mon garçon'},
#  {'id': '17069',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/sbtVL4OTXm9VGT5SMosj7yUHu5W.jpg',
#   'slug': 'bonjour-tristesse-f11423',
#   'title': 'Bonjour Tristesse'},
#  {'id': '31234',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/tsmitsKE7UTR5LEMbnHS34CV26y.jpg',
#   'slug': 'a-ciambra',
#   'title': 'A Ciambra'},
#  {'id': '26320',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/nfudzwjd9oRoBgH2U7GjSKM1Z9x.jpg',
#   'slug': 'au-revoir-la-haut',
#   'title': 'See You Up There'},
#  {'id': '20629',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5zctJPNIcgWvTm5HbvSP41aPzCt.jpg',
#   'slug': 'mal-de-pierres',
#   'title': 'From the Land of the Moon'},
#  {'id': '25951',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/3VEbB2jfUiZo85vpdLmQgIT7tk1.jpg',
#   'slug': 'the-nile-hilton-incident',
#   'title': 'The Nile Hilton Incident'},
#  {'id': '11557',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/pUPINQzu5OMLzPMDZwlgioNn0d4.jpg',
#   'slug': 'johnny-guitar-wenn-frauen-hassen',
#   'title': 'Johnny Guitar'},
#  {'id': '21123',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/sVvXqJHvrUmypVAyTwLCS9ttCOe.jpg',
#   'slug': 'happy-end-40042e5b-0b3d-431c-a4d2-488b81f94976',
#   'title': 'Happy End'},
#  {'id': '24820',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ckbUVwa9r7h348upwiRvjpl4sQp.jpg',
#   'slug': 'upstream-color',
#   'title': 'Upstream Color'},
#  {'id': '35347',
#   'poster_image_thumbnail': None,
#   'slug': 'the-nightingale-0e96d981-1edc-47ba-97c7-170f4a2e6bd0',
#   'title': 'The Nightingale'},
#  {'id': '29845',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/a4QdH1RG6jvzZ1SLmCI7vaDD9Ez.jpg',
#   'slug': 'god-s-not-dead',
#   'title': "God's Not Dead"},
#  {'id': '21188',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/dxxDCQb3CJzXOh8rCT5CbsG1ikj.jpg',
#   'slug': 'the-young-karl-marx',
#   'title': 'The Young Karl Marx'},
#  {'id': '21020',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/yCt9jWUFNpWLSiNpShZr9JFF9oD.jpg',
#   'slug': 'the-beguiled',
#   'title': 'The Beguiled'},
#  {'id': '30288',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cz0egudCsfsTzwUAL03A5UzoHGT.jpg',
#   'slug': 'good-time',
#   'title': 'Good Time'},
#  {'id': '23697',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vwqVsNVwvjyPMmIYWho0WMXygML.jpg',
#   'slug': 'rara',
#   'title': 'Rara'},
#  {'id': '28559',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/8EfNuERL9weFWblnMUabinB2Gwb.jpg',
#   'slug': 'a083080d-0d81-456a-bf36-9b530e528d4a',
#   'title': 'A Gentle Creature'},
#  {'id': '34171',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xBruhmvSkJSazvGKWqcY1LYcoje.jpg',
#   'slug': 'party',
#   'title': 'The Party'},
#  {'id': '32363',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5q5QnaRg0cACuwOwdrBj7lxY7gV.jpg',
#   'slug': 'petit-paysan',
#   'title': 'Bloody Milk'},
#  {'id': '30190',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5kdrXtk5FmzXjL5ZmghSswmaK8v.jpg',
#   'slug': 'especes-menacees',
#   'title': None},
#  {'id': '26560',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7APLVpsGzXPJw16ZuBtXICxq8B9.jpg',
#   'slug': 'untitled-detroit-riots-project',
#   'title': 'Detroit'},
#  {'id': '21705',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xq1Ugd62d23K2knRUx6xxuALTZB.jpg',
#   'slug': 'kimi-no-na-wa',
#   'title': 'Your Name.'},
#  {'id': '9122',
#   'poster_image_thumbnail': None,
#   'slug': 'fallen-angels',
#   'title': None},
#  {'id': '25821',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/1gHLxIFqd5Ne6IJNZ6kOICvUPAq.jpg',
#   'slug': 'victoria-and-abdul',
#   'title': 'Victoria & Abdul'},
#  {'id': '34952',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4y5iHYxCFQNIFEuW6owWfXACBJG.jpg',
#   'slug': 'saturday-night-and-sunday-morning',
#   'title': 'Saturday Night and Sunday Morning'},
#  {'id': '5601',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/6AlKDmfVi5cqQFprxJCf1FWihPk.jpg',
#   'slug': 'dirty-harry',
#   'title': 'Dirty Harry'},
#  {'id': '20570',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ylXCdC106IKiarftHkcacasaAcb.jpg',
#   'slug': 'la-la-land',
#   'title': 'La La Land'},
#  {'id': '4819',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/nDs6gn1VH5MmF7l8G8UABBBX0G1.jpg',
#   'slug': 'spring-breakers',
#   'title': 'Spring Breakers'},
#  {'id': '32009',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/34zJ9Rr05dbhsuNo2CCvfmgaEmw.jpg',
#   'slug': 'gabriel-e-a-montanha',
#   'title': 'Gabriel and the Mountain'},
#  {'id': '29715',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/rtaVI9YtbkT3nkfVtm3W7H60BIE.jpg',
#   'slug': 'a-taste-of-honey',
#   'title': 'A Taste of Honey'},
#  {'id': '29712',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/kYNGh9vKwwZEK49Uy2Wvrli3u53.jpg',
#   'slug': 'the-loneliness-of-the-long-distance-runner',
#   'title': 'The Loneliness of the Long Distance Runner'},
#  {'id': '26526',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vKOaIRNuAtWnJNCIJ0Igd9zorRY.jpg',
#   'slug': 'the-killing-of-a-sacred-deer',
#   'title': 'The Killing of a Sacred Deer'},
#  {'id': '20788',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qmi2dsuoyzZdJ0WFZYQazbX8ILj.jpg',
#   'slug': 'day-6',
#   'title': 'mother!'},
#  {'id': '16351',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/iHOFfZ55RzB9qchl9eywFAgl5P9.jpg',
#   'slug': 'adama',
#   'title': 'Adama'},
#  {'id': '24070',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/1NjTS3FDcGYzC0L5yaMkfQ3mULm.jpg',
#   'slug': 'egon-schiele-tod-und-maedchen',
#   'title': 'Egon Schiele: Death and the Maiden'},
#  {'id': '23226',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/h7fMxriK1hmigT3gtFZPkQjgKtQ.jpg',
#   'slug': 'the-architect',
#   'title': 'The Architect'},
#  {'id': '24384',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ksx6hvl5j04qgGeW0Y1ajkXx5KB.jpg',
#   'slug': 'logan-lucky',
#   'title': 'Logan Lucky'},
#  {'id': '33099',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/l9noBc7vLAHOKVB1I3FwxBaFY3h.jpg',
#   'slug': 'djam',
#   'title': None},
#  {'id': '24915',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/jDZLd4fgnpmtvNdGDE2c0asfkO9.jpg',
#   'slug': 'viceroy-s-house',
#   'title': "Viceroy's House"},
#  {'id': '20492',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bOXBV303Fgkzn2K4FeKDc0O31q4.jpg',
#   'slug': 'dunkirk',
#   'title': 'Dunkirk'},
#  {'id': '16070',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xSE4NBFDzqedwa4AIj99r1Z7ljF.jpg',
#   'slug': 'creed',
#   'title': 'Creed'},
#  {'id': '31923',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qsjZ3FCPKEi4zZ1XqUh0CEPWS6H.jpg',
#   'slug': 'demain-et-tous-les-autres-jours',
#   'title': None},
#  {'id': '16223',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xSIl7zldSG75nXVvtsZL7hJ2M0Y.jpg',
#   'slug': 'mikro-sprit',
#   'title': 'Microbe and Gasoline'},
#  {'id': '6151',
#   'poster_image_thumbnail': 'http://imageserver.krankikom.de/film/f11443.jpg',
#   'slug': 'zabriskie-point',
#   'title': None},
#  {'id': '29130',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bqoXDdbuB9fRQjA8FuZLhom1ymR.jpg',
#   'slug': 'gauguin',
#   'title': 'Gauguin – Voyage de Tahiti'},
#  {'id': '21594',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/9E2y5Q7WlCVNEhP5GiVTjhEhx1o.jpg',
#   'slug': 'it',
#   'title': 'It'},
#  {'id': '27557',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/uguWEoZelSSckxgiQctlkZ6gpfU.jpg',
#   'slug': 'testrol-es-lelekrol',
#   'title': 'On Body and Soul'},
#  {'id': '3374',
#   'poster_image_thumbnail': None,
#   'slug': 'barry-lyndon',
#   'title': None},
#  {'id': '12218',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/avy7IR8UMlIIyE2BPCI4plW4Csc.jpg',
#   'slug': 'thor-ragnarok',
#   'title': 'Thor: Ragnarok'},
#  {'id': '34611',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/92dj9KDsD9n30x99ry29eRvgsD9.jpg',
#   'slug': 'nina',
#   'title': 'Nina'},
#  {'id': '21230',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/g7ifEh3XBKftVA0g1zz9lXORm7l.jpg',
#   'slug': 'the-square',
#   'title': 'The Square'},
#  {'id': '13669',
#   'poster_image_thumbnail': 'http://imageserver.krankikom.de/film/f211487.jpg',
#   'slug': 'diese-nacht',
#   'title': None},
#  {'id': '35204',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/wuLf8sXaHOqqcLdIC6TmH3ebgD.jpg',
#   'slug': 'leon-morin-pretre',
#   'title': 'Léon Morin, Priest'},
#  {'id': '25395',
#   'poster_image_thumbnail': None,
#   'slug': 'chun-gwong-cha-sit',
#   'title': None},
#  {'id': '3801',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/sLYdcz7easaS7CmJGwQcVVYZqiF.jpg',
#   'slug': 'life-of-pi-schiffbruch-mit-tiger',
#   'title': 'Life of Pi'},
#  {'id': '13483',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/l94Zxt4szlbt1inateoAXAqKVG1.jpg',
#   'slug': 'denen-man-nicht-vergibt',
#   'title': 'Unforgiven'},
#  {'id': '4458',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/rHvKWARrhNwSjbTMJrn5v4LtUJE.jpg',
#   'slug': 'belle-de-jour-schoene-des-tages',
#   'title': 'Belle de Jour'},
#  {'id': '30299',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/nl0r4nUKaDwQ9ifLyiTR1oZQx8w.jpg',
#   'slug': 'posoki',
#   'title': 'Directions'},
#  {'id': '32589',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/1zG9B1H3hJYHBG1y9AXC0xBDNAy.jpg',
#   'slug': 'tehran-taboo',
#   'title': 'Tehran Taboo'},
#  {'id': '30305',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/uyGiTEZDT1m4m2VM3piP9NoszV4.jpg',
#   'slug': '120-battements-par-minute',
#   'title': '120 Beats Per Minute'},
#  {'id': '28097',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/l2iYnRcXIfR0eVUPnVkVfytntMM.jpg',
#   'slug': 'insyriated',
#   'title': 'Insyriated'},
#  {'id': '20839',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/mzVEuBnH7U6sqYnDvnCUujcExCp.jpg',
#   'slug': 'beb9bdd2-4dc6-4291-9bff-38a0faf09836',
#   'title': 'In This Corner of the World'},
#  {'id': '3398',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4GpwvwDjgwiShr1UBJIn5fk1gwT.jpg',
#   'slug': 'fight-club',
#   'title': 'Fight Club'},
#  {'id': '18699',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/y0hJt5WurqDplEzTnrrMCwE1YIZ.jpg',
#   'slug': 'zero-dark-thirty',
#   'title': 'Zero Dark Thirty'},
#  {'id': '10778',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/foMdJ8ijYk5G1Jn0HZRplFTu9Dt.jpg',
#   'slug': 'leviathan-f323686',
#   'title': 'Leviathan'},
#  {'id': '16755',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/rYfnOaYYgAuoI8R0JiAV72jAESS.jpg',
#   'slug': 'beruf-reporter',
#   'title': 'The Passenger'},
#  {'id': '30532',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ybJ0iNCGj7GU2TkBi0PaFc4y5x0.jpg',
#   'slug': 'le-redoutable',
#   'title': 'Redoubtable'},
#  {'id': '19706',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qplM1tq6X1I1yMuANV2Cc8yeAuJ.jpg',
#   'slug': 'the-return',
#   'title': 'The Return'},
#  {'id': '7237',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/mSrfyFGeSZ58sfDvtVz8TvTQyfX.jpg',
#   'slug': 'nostalghia',
#   'title': 'Nostalgia'},
#  {'id': '25246',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vYaWP1Pt8n9npX5eaynZHP7MIRV.jpg',
#   'slug': 'his-girl-friday',
#   'title': 'His Girl Friday'},
#  {'id': '24838',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qlrhwUDe7YOZujAYanK6ij2vbY5.jpg',
#   'slug': 'loving-vincent',
#   'title': 'Loving Vincent'},
#  {'id': '26503',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5XX7sx3sIgwuoNw4WOJj00wbLbH.jpg',
#   'slug': 'otez-moi-d-un-doute',
#   'title': 'Just to Be Sure'},
#  {'id': '3994',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/rgIrQ5qeqAxenqweSUkUx5whTan.jpg',
#   'slug': 'gloria',
#   'title': 'Gloria'},
#  {'id': '26598',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/p0o3yoJmsEMMhMPAMLl6VI7MomI.jpg',
#   'slug': 'loveless',
#   'title': 'Loveless'},
#  {'id': '21251',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/d5fLQ9ZMa1jZ2mODCv5lOWJDugX.jpg',
#   'slug': 'the-glass-castle',
#   'title': 'The Glass Castle'},
#  {'id': '17005',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7SsUvaN6uS9KfTyw0pz3vrdjJkm.jpg',
#   'slug': 'die-piratenkoenigin',
#   'title': 'Anne of the Indies'},
#  {'id': '3481',
#   'poster_image_thumbnail': 'http://imageserver.krankikom.de/film/f142284.jpg',
#   'slug': '2046',
#   'title': None},
#  {'id': '25890',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/c5JQJZoxdttJx26MdWzFiTs8nNp.jpg',
#   'slug': 'nos-annees-folles',
#   'title': 'Golden Years'},
#  {'id': '20451',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/p6hIHtQQsGIzLbdsL9QuHV4KJbL.jpg',
#   'slug': 'certain-women',
#   'title': 'Certain Women'},
#  {'id': '7240',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/9zknVczWOLhTKnT9nbX2IOCHtZn.jpg',
#   'slug': 'slumdog-millionaer',
#   'title': 'Slumdog Millionaire'}]

# %%
print("there are {} movies found".format(str(len(movies))))
# Out:
# there are 82 movies found

# %% [markdown]
# ## Result
# make the list more readable by only keeping the title of the movies

# %%
for movie in movies :
    if movie["title"] is not None:    
        print(movie["title"] )
    else:
        if movie["slug"] is not None:
            print(movie["slug"].replace('-',' '))
# Out:
# The Jungle Book
# My Life as a Dog
# American Made
# Mon garçon
# Bonjour Tristesse
# A Ciambra
# See You Up There
# From the Land of the Moon
# The Nile Hilton Incident
# Johnny Guitar
# Happy End
# Upstream Color
# The Nightingale
# God's Not Dead
# The Young Karl Marx
# The Beguiled
# Good Time
# Rara
# A Gentle Creature
# The Party
# Bloody Milk
# especes menacees
# Detroit
# Your Name.
# fallen angels
# Victoria & Abdul
# Saturday Night and Sunday Morning
# Dirty Harry
# La La Land
# Spring Breakers
# Gabriel and the Mountain
# A Taste of Honey
# The Loneliness of the Long Distance Runner
# The Killing of a Sacred Deer
# mother!
# Adama
# Egon Schiele: Death and the Maiden
# The Architect
# Logan Lucky
# djam
# Viceroy's House
# Dunkirk
# Creed
# demain et tous les autres jours
# Microbe and Gasoline
# zabriskie point
# Gauguin – Voyage de Tahiti
# It
# On Body and Soul
# barry lyndon
# Thor: Ragnarok
# Nina
# The Square
# diese nacht
# Léon Morin, Priest
# chun gwong cha sit
# Life of Pi
# Unforgiven
# Belle de Jour
# Directions
# Tehran Taboo
# 120 Beats Per Minute
# Insyriated
# In This Corner of the World
# Fight Club
# Zero Dark Thirty
# Leviathan
# The Passenger
# Redoubtable
# The Return
# Nostalgia
# His Girl Friday
# Loving Vincent
# Just to Be Sure
# Gloria
# Loveless
# The Glass Castle
# Anne of the Indies
# 2046
# Golden Years
# Certain Women
# Slumdog Millionaire
